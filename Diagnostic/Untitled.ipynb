# %%
import clingo
import os
import pandas as pd
import textwrap

# %%
# Path to the folder containing the CSV files
folder_path = 'data'
dataframes = []
def readDatasInPanda(file_path):
#we probaply should not combine all the files in one dataset just now for testing
    df = pd.read_csv(file_path)

        # Append the cleaned DataFrame to the list
    dataframes.append(df)

# Combine all DataFrames into one
    pandas_data = pd.concat(dataframes, ignore_index=True)

# Display the first few rows of the combined DataFrame
    return pandas_data
    #voltages_over_time = combined_data['ex1.r_load.v']
# Save the combined DataFrame to a new CSV file (optional)
#combined_data.to_csv('combined_data.csv', index=False)

# %%
readDatasInPanda("./data/P3Ex1_Testbench_7_res.csv")["ex1.r_load.v"]
# Out:
# 0       10.576923
# 1       10.576923
# 2       10.576923
# 3       10.576923
# 4       10.576923
#           ...
# 5998     6.250000
# 5999     6.250000
# 6000     6.250000
# 6001     6.250000
# 6002     6.250000
# Name: ex1.r_load.v, Length: 6003, dtype: float64

# %%
def classify_voltage(value: float) -> str:
    """
    Map a real-valued voltage to one of the qualitative labels:
      vlow < (vmid,vlow) < vmid < (vmax,vmid) < vmax
    """
    return int(value)
    if value >= 12.6:
        return "vmax"
    elif value >= 7.0:
        return "(vmax,vmid)"
    elif value >= 8:
        return "vmid"
    elif value >= 7:
        return "(vmid,vlow)"
    else:
        return "vlow"

# %%
DOMAIN_ASP = textwrap.dedent("""% Constants
% ********************
% 1. Define Constants
% ********************

vmin(10).
vmax(15).

% ********************
% 2. Define Entities
% ********************

% Batteries
battery(b1). 
battery(b2). 
battery(b3).

% Switches
switch(switch1). 
switch(switch2). 
switch(switch3).

% ********************
% 3. Define Connections
% ********************

% Each switch is connected to a specific battery
connected(switch1, b1).
connected(switch2, b2).
connected(switch3, b3).

% ********************
% 4. Define Battery Properties
% ********************

% Battery voltages at each time step
battery_voltage(b1, 12, 0).
battery_voltage(b2, 11, 0).
battery_voltage(b3, 13, 0).

% Expected voltages for fault detection
expected_voltage(b1, 10).
expected_voltage(b2, 10).
expected_voltage(b3, 10).

% ********************
% 5. Define Switch States
% ********************

% ********************
% 6. Define Time Steps
% ********************

% Define time steps
time(0..96026).

% ********************
% 7. Calculate Total Voltage
% ********************

% Total voltage is the sum of voltages from all connected (on) batteries at time T
total_voltage(V, T) :- 
    time(T),
    V = #sum { Vb, S : switch_state(S, on, T), connected(S, B), battery_voltage(B, Vb, T) }.

% ********************
% 8. Controller Logic
% ********************

% Controller: Activate switches when voltage < vmin at time T
activate_switch(S, T) :- 
    total_voltage(V, T), 
    vmin(Vmin),        
    V < Vmin,          
    switch(S),
    switch_state(S, off, T),
    can_activate(S),
    time(T).

% Controller: Deactivate switches when voltage > vmax at time T
deactivate_switch(S, T) :- 
    total_voltage(V, T),
    vmax(Vmax),        
    V > Vmax,          
    switch(S),
    switch_state(S, on, T),
    can_deactivate(S),
    time(T).

% Activation order: switch1, then switch2, then switch3
can_activate(switch1).
can_activate(switch2) :- switch_state(switch1, on, T), time(T).
can_activate(switch3) :- switch_state(switch2, on, T), time(T).

% Deactivation order: switch3, then switch2, then switch1
can_deactivate(switch3).
can_deactivate(switch2) :- switch_state(switch3, off, T), time(T).
can_deactivate(switch1) :- switch_state(switch2, off, T), time(T).

% Apply activation to the next time step
switch_state(S, on, T+1) :- activate_switch(S, T).

% Apply deactivation to the next time step
switch_state(S, off, T+1) :- deactivate_switch(S, T).

% Carry forward the state if no change
switch_state(S, State, T+1) :- 
    switch_state(S, State, T),
    not activate_switch(S, T),
    not deactivate_switch(S, T),
    time(T+1).

% ********************
% 9. Fault Detection
% ********************

% Battery Faults at each time step
battery_fault(S, T) :- 
    connected(S, B),
    switch_state(S, on, T),
    battery_voltage(B, Vb, T),
    Vb < expected_voltage(B),
    time(T).

% Switch Faults at each time step
switch_fault(S, T) :- 
    activate_switch(S, T),
    switch_state(S, off, T+1),
    time(T).

switch_fault(S, T) :- 
    deactivate_switch(S, T),
    switch_state(S, on, T+1),
    time(T).

""")

# %%
def build_facts_from_csv(pandasData) -> str:
    """
    Reads time, Vbattery1, Vbattery2, Vbattery3, Vout, switch1, switch2, switch3 from a CSV file,
    maps Vout to qualitative states, and returns ASP facts as a string.
    """
    lines = []

    for index, row in pandasData.iterrows():
        # Extract and classify output voltage
        t = index  # Convert time to integer
        vout_value = float(row["ex1.r_load.v"])  # Extract voltage value

        # Classify Vout into qualitative state
        vout_state = classify_voltage(vout_value)

        # Append time and voltage facts
        lines.append(f"time({t}).")
        lines.append(f"total_voltage({vout_state},{t}).")

        # Extract and process switch states
        switch1_state = row["ex1.s1.mode"]
        switch2_state = row["ex1.s2.mode"]
        switch3_state = row["ex1.s3.mode"]  # Corrected key

        
        # Ensure switch states are either 'on' or 'off'
        #print( str(switch1_state) == "1.0")
        #print(switch1_state)
        switch1 = "on" if str(switch1_state) == "1.0" else "off"
        switch2 = "on" if str(switch2_state) == "1.0" else "off"
        switch3 = "on" if str(switch3_state) == "1.0" else "off"

        # Append switchState facts
        lines.append(f"switch_state(switch1,{switch1},{t}).")
        lines.append(f"switch_state(switch2,{switch2},{t}).")
        lines.append(f"switch_state(switch3,{switch3},{t}).")
        #if index == 100: 
          #  break
    return "\n".join(lines)

# %%
def on_model(model, output):
    """
    Callback function to process each model found by Clingo.
    Collects the voltage assignments and any detected faults.
    """
    atoms = model.symbols(shown=True)
    battery_assignments = [str(a) for a in atoms if a.name == "voltage"]
   # heater_assignments = [str(a) for a in atoms if a.name == "heaterVoltage"]
    faults = [str(a) for a in atoms if a.name == "faulty"]

    output.append((battery_assignments, faults))

# %%
def diagnose(csv_path: str, asp_output_path: str = "diagnosis_program.asp"):
    # 1) Build ASP facts from the CSV
    data_facts = build_facts_from_csv(readDatasInPanda(csv_path))
    print("Finished reading data\n")
    # 2) Combine domain + data
    program = f"{DOMAIN_ASP}\n\n% Observed Data:\n{data_facts}\n"

    # 4) Optionally, print the complete program for debugging
    print("Complete ASP Program:\n")
    try:
        with open(asp_output_path, "w") as asp_file:
            asp_file.write(program)
        print(f"ASP program written to '{asp_output_path}'.")
    except IOError as e:
        print(f"Error writing ASP program to file: {e}")
        return
    
    print("Init clingo\n")
    # 3) Initialize Clingo Control
    ctl = clingo.Control()
    
    # 4) Add the program
    ctl.add("base", [], program)
    ctl.ground([("base", [])])
    print("Finished Init clingo\n")
    # 5) Prepare to collect solutions
    solutions = []

    # 6) Define the callback
    def callback(model):
        battery_assignments = []
        faults = []
        for atom in model.symbols(shown=True):
            if atom.name == "total_voltage":
                battery_assignments.append(str(atom))
            elif atom.name == "battery_fault" or atom.name == "switch_fault":
                faults.append(str(atom))
        solutions.append((battery_assignments, faults))

    # 7) Solve
    print("Start solving with clingo\n")
    ctl.solve(on_model=callback)
    print("Finished solving with clingo\n")
    # 8) Process and Print Results
    if not solutions:
        print("No solutions found. Possible multiple faults or inconsistent data.")
    else:
        print(f"Found {len(solutions)} solution(s):\n")
        for idx, (bats, faults) in enumerate(solutions, start=1):
            print(f"--- Solution #{idx} ---")
            print("Battery Voltage Assignments:")
            #for bat in sorted(bats):
               # print(f"  {bat}")
            print("Fault Hypotheses:")
            if faults:
                for fault in faults:
                    print(f"  {fault}")
            else:
                print("  No faults detected.")
            print()

# %%
diagnose("./data/P3Ex1_Testbench_7_res.csv")
# Out:
# Finished reading data
#
# Complete ASP Program:
#
# ASP program written to 'diagnosis_program.asp'.
# Init clingo
#
# Finished Init clingo
#
# Start solving with clingo
#
# Finished solving with clingo
#
# Found 1 solution(s):
#
# --- Solution #1 ---
# Battery Voltage Assignments:
# Fault Hypotheses:
#   battery_fault(switch1,0)
#   switch_fault(switch2,1)
#   switch_fault(switch3,1)
#   switch_fault(switch2,2)
#   switch_fault(switch3,2)
#   switch_fault(switch2,3)
#   switch_fault(switch3,3)
#   switch_fault(switch2,4)
#   switch_fault(switch3,4)
#   switch_fault(switch2,5)
#   switch_fault(switch3,5)
#   switch_fault(switch2,6)
#   switch_fault(switch3,6)
#   switch_fault(switch2,7)
#   switch_fault(switch3,7)
#   switch_fault(switch2,8)
#   switch_fault(switch3,8)
#   switch_fault(switch2,9)
#   switch_fault(switch3,9)
#   switch_fault(switch2,10)
#   switch_fault(switch3,10)
#   switch_fault(switch2,11)
#   switch_fault(switch3,11)
#   switch_fault(switch2,12)
#   switch_fault(switch3,12)
#   switch_fault(switch2,13)
#   switch_fault(switch3,13)
#   switch_fault(switch2,14)
#   switch_fault(switch3,14)
#   switch_fault(switch2,15)
#   switch_fault(switch3,15)
#   switch_fault(switch2,16)
#   switch_fault(switch3,16)
#   switch_fault(switch2,17)
#   switch_fault(switch3,17)
#   switch_fault(switch2,18)
#   switch_fault(switch3,18)
#   switch_fault(switch2,19)
#   switch_fault(switch3,19)
#   switch_fault(switch2,20)
#   switch_fault(switch3,20)
#   switch_fault(switch2,21)
#   switch_fault(switch3,21)
#   switch_fault(switch2,22)
#   switch_fault(switch3,22)
#   switch_fault(switch2,23)
#   switch_fault(switch3,23)
#   switch_fault(switch2,24)
#   switch_fault(switch3,24)
#   switch_fault(switch2,25)
#   switch_fault(switch3,25)
#   switch_fault(switch2,26)
#   switch_fault(switch3,26)
#   switch_fault(switch2,27)
#   switch_fault(switch3,27)
#   switch_fault(switch2,28)
#   switch_fault(switch3,28)
#   switch_fault(switch2,29)
#   switch_fault(switch3,29)
#   switch_fault(switch2,30)
#   switch_fault(switch3,30)
#   switch_fault(switch2,31)
#   switch_fault(switch3,31)
#   switch_fault(switch2,32)
#   switch_fault(switch3,32)
#   switch_fault(switch2,33)
#   switch_fault(switch3,33)
#   switch_fault(switch2,34)
#   switch_fault(switch3,34)
#   switch_fault(switch2,35)
#   switch_fault(switch3,35)
#   switch_fault(switch2,36)
#   switch_fault(switch3,36)
#   switch_fault(switch2,37)
#   switch_fault(switch3,37)
#   switch_fault(switch2,38)
#   switch_fault(switch3,38)
#   switch_fault(switch2,39)
#   switch_fault(switch3,39)
#   switch_fault(switch2,40)
#   switch_fault(switch3,40)
#   switch_fault(switch2,41)
#   switch_fault(switch3,41)
#   switch_fault(switch2,42)
#   switch_fault(switch3,42)
#   switch_fault(switch2,43)
#   switch_fault(switch3,43)
#   switch_fault(switch2,44)
#   switch_fault(switch3,44)
#   switch_fault(switch2,45)
#   switch_fault(switch3,45)
#   switch_fault(switch2,46)
#   switch_fault(switch3,46)
#   switch_fault(switch2,47)
#   switch_fault(switch3,47)
#   switch_fault(switch2,48)
#   switch_fault(switch3,48)
#   switch_fault(switch2,49)
#   switch_fault(switch3,49)
#   switch_fault(switch2,50)
#   switch_fault(switch3,50)
#   switch_fault(switch2,51)
#   switch_fault(switch3,51)
#   switch_fault(switch2,52)
#   switch_fault(switch3,52)
#   switch_fault(switch2,53)
#   switch_fault(switch3,53)
#   switch_fault(switch2,54)
#   switch_fault(switch3,54)
#   switch_fault(switch2,55)
#   switch_fault(switch3,55)
#   switch_fault(switch2,56)
#   switch_fault(switch3,56)
#   switch_fault(switch2,57)
#   switch_fault(switch3,57)
#   switch_fault(switch2,58)
#   switch_fault(switch3,58)
#   switch_fault(switch2,59)
#   switch_fault(switch3,59)
#   switch_fault(switch2,60)
#   switch_fault(switch3,60)
#   switch_fault(switch2,61)
#   switch_fault(switch3,61)
#   switch_fault(switch2,62)
#   switch_fault(switch3,62)
#   switch_fault(switch2,63)
#   switch_fault(switch3,63)
#   switch_fault(switch2,64)
#   switch_fault(switch3,64)
#   switch_fault(switch2,65)
#   switch_fault(switch3,65)
#   switch_fault(switch2,66)
#   switch_fault(switch3,66)
#   switch_fault(switch2,67)
#   switch_fault(switch3,67)
#   switch_fault(switch2,68)
#   switch_fault(switch3,68)
#   switch_fault(switch2,69)
#   switch_fault(switch3,69)
#   switch_fault(switch2,70)
#   switch_fault(switch3,70)
#   switch_fault(switch2,71)
#   switch_fault(switch3,71)
#   switch_fault(switch2,72)
#   switch_fault(switch3,72)
#   switch_fault(switch2,73)
#   switch_fault(switch3,73)
#   switch_fault(switch2,74)
#   switch_fault(switch3,74)
#   switch_fault(switch2,75)
#   switch_fault(switch3,75)
#   switch_fault(switch2,76)
#   switch_fault(switch3,76)
#   switch_fault(switch2,77)
#   switch_fault(switch3,77)
#   switch_fault(switch2,78)
#   switch_fault(switch3,78)
#   switch_fault(switch2,79)
#   switch_fault(switch3,79)
#   switch_fault(switch2,80)
#   switch_fault(switch3,80)
#   switch_fault(switch2,81)
#   switch_fault(switch3,81)
#   switch_fault(switch2,82)
#   switch_fault(switch3,82)
#   switch_fault(switch2,83)
#   switch_fault(switch3,83)
#   switch_fault(switch2,84)
#   switch_fault(switch3,84)
#   switch_fault(switch2,85)
#   switch_fault(switch3,85)
#   switch_fault(switch2,86)
#   switch_fault(switch3,86)
#   switch_fault(switch2,87)
#   switch_fault(switch3,87)
#   switch_fault(switch2,88)
#   switch_fault(switch3,88)
#   switch_fault(switch2,89)
#   switch_fault(switch3,89)
#   switch_fault(switch2,90)
#   switch_fault(switch3,90)
#   switch_fault(switch2,91)
#   switch_fault(switch3,91)
#   switch_fault(switch2,92)
#   switch_fault(switch3,92)
#   switch_fault(switch2,93)
#   switch_fault(switch3,93)
#   switch_fault(switch2,94)
#   switch_fault(switch3,94)
#   switch_fault(switch2,95)
#   switch_fault(switch3,95)
#   switch_fault(switch2,96)
#   switch_fault(switch3,96)
#   switch_fault(switch2,97)
#   switch_fault(switch3,97)
#   switch_fault(switch2,98)
#   switch_fault(switch3,98)
#   switch_fault(switch2,99)
#   switch_fault(switch3,99)
#   switch_fault(switch2,100)
#   switch_fault(switch3,100)
#   switch_fault(switch2,101)
#   switch_fault(switch3,101)
#   switch_fault(switch2,102)
#   switch_fault(switch3,102)
#   switch_fault(switch2,103)
#   switch_fault(switch3,103)
#   switch_fault(switch2,104)
#   switch_fault(switch3,104)
#   switch_fault(switch2,105)
#   switch_fault(switch3,105)
#   switch_fault(switch2,106)
#   switch_fault(switch3,106)
#   switch_fault(switch2,107)
#   switch_fault(switch3,107)
#   switch_fault(switch2,108)
#   switch_fault(switch3,108)
#   switch_fault(switch2,109)
#   switch_fault(switch3,109)
#   switch_fault(switch2,110)
#   switch_fault(switch3,110)
#   switch_fault(switch2,111)
#   switch_fault(switch3,111)
#   switch_fault(switch2,112)
#   switch_fault(switch3,112)
#   switch_fault(switch2,113)
#   switch_fault(switch3,113)
#   switch_fault(switch2,114)
#   switch_fault(switch3,114)
#   switch_fault(switch2,115)
#   switch_fault(switch3,115)
#   switch_fault(switch2,116)
#   switch_fault(switch3,116)
#   switch_fault(switch2,117)
#   switch_fault(switch3,117)
#   switch_fault(switch2,118)
#   switch_fault(switch3,118)
#   switch_fault(switch2,119)
#   switch_fault(switch3,119)
#   switch_fault(switch2,120)
#   switch_fault(switch3,120)
#   switch_fault(switch2,121)
#   switch_fault(switch3,121)
#   switch_fault(switch2,122)
#   switch_fault(switch3,122)
#   switch_fault(switch2,123)
#   switch_fault(switch3,123)
#   switch_fault(switch2,124)
#   switch_fault(switch3,124)
#   switch_fault(switch2,125)
#   switch_fault(switch3,125)
#   switch_fault(switch2,126)
#   switch_fault(switch3,126)
#   switch_fault(switch2,127)
#   switch_fault(switch3,127)
#   switch_fault(switch2,128)
#   switch_fault(switch3,128)
#   switch_fault(switch2,129)
#   switch_fault(switch3,129)
#   switch_fault(switch2,130)
#   switch_fault(switch3,130)
#   switch_fault(switch2,131)
#   switch_fault(switch3,131)
#   switch_fault(switch2,132)
#   switch_fault(switch3,132)
#   switch_fault(switch2,133)
#   switch_fault(switch3,133)
#   switch_fault(switch2,134)
#   switch_fault(switch3,134)
#   switch_fault(switch2,135)
#   switch_fault(switch3,135)
#   switch_fault(switch2,136)
#   switch_fault(switch3,136)
#   switch_fault(switch2,137)
#   switch_fault(switch3,137)
#   switch_fault(switch2,138)
#   switch_fault(switch3,138)
#   switch_fault(switch2,139)
#   switch_fault(switch3,139)
#   switch_fault(switch2,140)
#   switch_fault(switch3,140)
#   switch_fault(switch2,141)
#   switch_fault(switch3,141)
#   switch_fault(switch2,142)
#   switch_fault(switch3,142)
#   switch_fault(switch2,143)
#   switch_fault(switch3,143)
#   switch_fault(switch2,144)
#   switch_fault(switch3,144)
#   switch_fault(switch2,145)
#   switch_fault(switch3,145)
#   switch_fault(switch2,146)
#   switch_fault(switch3,146)
#   switch_fault(switch2,147)
#   switch_fault(switch3,147)
#   switch_fault(switch2,148)
#   switch_fault(switch3,148)
#   switch_fault(switch2,149)
#   switch_fault(switch3,149)
#   switch_fault(switch2,150)
#   switch_fault(switch3,150)
#   switch_fault(switch2,151)
#   switch_fault(switch3,151)
#   switch_fault(switch2,152)
#   switch_fault(switch3,152)
#   switch_fault(switch2,153)
#   switch_fault(switch3,153)
#   switch_fault(switch2,154)
#   switch_fault(switch3,154)
#   switch_fault(switch2,155)
#   switch_fault(switch3,155)
#   switch_fault(switch2,156)
#   switch_fault(switch3,156)
#   switch_fault(switch2,157)
#   switch_fault(switch3,157)
#   switch_fault(switch2,158)
#   switch_fault(switch3,158)
#   switch_fault(switch2,159)
#   switch_fault(switch3,159)
#   switch_fault(switch2,160)
#   switch_fault(switch3,160)
#   switch_fault(switch2,161)
#   switch_fault(switch3,161)
#   switch_fault(switch2,162)
#   switch_fault(switch3,162)
#   switch_fault(switch2,163)
#   switch_fault(switch3,163)
#   switch_fault(switch2,164)
#   switch_fault(switch3,164)
#   switch_fault(switch2,165)
#   switch_fault(switch3,165)
#   switch_fault(switch2,166)
#   switch_fault(switch3,166)
#   switch_fault(switch2,167)
#   switch_fault(switch3,167)
#   switch_fault(switch2,168)
#   switch_fault(switch3,168)
#   switch_fault(switch2,169)
#   switch_fault(switch3,169)
#   switch_fault(switch2,170)
#   switch_fault(switch3,170)
#   switch_fault(switch2,171)
#   switch_fault(switch3,171)
#   switch_fault(switch2,172)
#   switch_fault(switch3,172)
#   switch_fault(switch2,173)
#   switch_fault(switch3,173)
#   switch_fault(switch2,174)
#   switch_fault(switch3,174)
#   switch_fault(switch2,175)
#   switch_fault(switch3,175)
#   switch_fault(switch2,176)
#   switch_fault(switch3,176)
#   switch_fault(switch2,177)
#   switch_fault(switch3,177)
#   switch_fault(switch2,178)
#   switch_fault(switch3,178)
#   switch_fault(switch2,179)
#   switch_fault(switch3,179)
#   switch_fault(switch2,180)
#   switch_fault(switch3,180)
#   switch_fault(switch2,181)
#   switch_fault(switch3,181)
#   switch_fault(switch2,182)
#   switch_fault(switch3,182)
#   switch_fault(switch2,183)
#   switch_fault(switch3,183)
#   switch_fault(switch2,184)
#   switch_fault(switch3,184)
#   switch_fault(switch2,185)
#   switch_fault(switch3,185)
#   switch_fault(switch2,186)
#   switch_fault(switch3,186)
#   switch_fault(switch2,187)
#   switch_fault(switch3,187)
#   switch_fault(switch2,188)
#   switch_fault(switch3,188)
#   switch_fault(switch2,189)
#   switch_fault(switch3,189)
#   switch_fault(switch2,190)
#   switch_fault(switch3,190)
#   switch_fault(switch2,191)
#   switch_fault(switch3,191)
#   switch_fault(switch2,192)
#   switch_fault(switch3,192)
#   switch_fault(switch2,193)
#   switch_fault(switch3,193)
#   switch_fault(switch2,194)
#   switch_fault(switch3,194)
#   switch_fault(switch2,195)
#   switch_fault(switch3,195)
#   switch_fault(switch2,196)
#   switch_fault(switch3,196)
#   switch_fault(switch2,197)
#   switch_fault(switch3,197)
#   switch_fault(switch2,198)
#   switch_fault(switch3,198)
#   switch_fault(switch2,199)
#   switch_fault(switch3,199)
#   switch_fault(switch2,200)
#   switch_fault(switch3,200)
#   switch_fault(switch2,201)
#   switch_fault(switch3,201)
#   switch_fault(switch2,202)
#   switch_fault(switch3,202)
#   switch_fault(switch2,203)
#   switch_fault(switch3,203)
#   switch_fault(switch2,204)
#   switch_fault(switch3,204)
#   switch_fault(switch2,205)
#   switch_fault(switch3,205)
#   switch_fault(switch2,206)
#   switch_fault(switch3,206)
#   switch_fault(switch2,207)
#   switch_fault(switch3,207)
#   switch_fault(switch2,208)
#   switch_fault(switch3,208)
#   switch_fault(switch2,209)
#   switch_fault(switch3,209)
#   switch_fault(switch2,210)
#   switch_fault(switch3,210)
#   switch_fault(switch2,211)
#   switch_fault(switch3,211)
#   switch_fault(switch2,212)
#   switch_fault(switch3,212)
#   switch_fault(switch2,213)
#   switch_fault(switch3,213)
#   switch_fault(switch2,214)
#   switch_fault(switch3,214)
#   switch_fault(switch2,215)
#   switch_fault(switch3,215)
#   switch_fault(switch2,216)
#   switch_fault(switch3,216)
#   switch_fault(switch2,217)
#   switch_fault(switch3,217)
#   switch_fault(switch2,218)
#   switch_fault(switch3,218)
#   switch_fault(switch2,219)
#   switch_fault(switch3,219)
#   switch_fault(switch2,220)
#   switch_fault(switch3,220)
#   switch_fault(switch2,221)
#   switch_fault(switch3,221)
#   switch_fault(switch2,222)
#   switch_fault(switch3,222)
#   switch_fault(switch2,223)
#   switch_fault(switch3,223)
#   switch_fault(switch2,224)
#   switch_fault(switch3,224)
#   switch_fault(switch2,225)
#   switch_fault(switch3,225)
#   switch_fault(switch2,226)
#   switch_fault(switch3,226)
#   switch_fault(switch2,227)
#   switch_fault(switch3,227)
#   switch_fault(switch2,228)
#   switch_fault(switch3,228)
#   switch_fault(switch2,229)
#   switch_fault(switch3,229)
#   switch_fault(switch2,230)
#   switch_fault(switch3,230)
#   switch_fault(switch2,231)
#   switch_fault(switch3,231)
#   switch_fault(switch2,232)
#   switch_fault(switch3,232)
#   switch_fault(switch2,233)
#   switch_fault(switch3,233)
#   switch_fault(switch2,234)
#   switch_fault(switch3,234)
#   switch_fault(switch2,235)
#   switch_fault(switch3,235)
#   switch_fault(switch2,236)
#   switch_fault(switch3,236)
#   switch_fault(switch2,237)
#   switch_fault(switch3,237)
#   switch_fault(switch2,238)
#   switch_fault(switch3,238)
#   switch_fault(switch2,239)
#   switch_fault(switch3,239)
#   switch_fault(switch2,240)
#   switch_fault(switch3,240)
#   switch_fault(switch2,241)
#   switch_fault(switch3,241)
#   switch_fault(switch2,242)
#   switch_fault(switch3,242)
#   switch_fault(switch2,243)
#   switch_fault(switch3,243)
#   switch_fault(switch2,244)
#   switch_fault(switch3,244)
#   switch_fault(switch2,245)
#   switch_fault(switch3,245)
#   switch_fault(switch2,246)
#   switch_fault(switch3,246)
#   switch_fault(switch2,247)
#   switch_fault(switch3,247)
#   switch_fault(switch2,248)
#   switch_fault(switch3,248)
#   switch_fault(switch2,249)
#   switch_fault(switch3,249)
#   switch_fault(switch2,250)
#   switch_fault(switch3,250)
#   switch_fault(switch2,251)
#   switch_fault(switch3,251)
#   switch_fault(switch2,252)
#   switch_fault(switch3,252)
#   switch_fault(switch2,253)
#   switch_fault(switch3,253)
#   switch_fault(switch2,254)
#   switch_fault(switch3,254)
#   switch_fault(switch2,255)
#   switch_fault(switch3,255)
#   switch_fault(switch2,256)
#   switch_fault(switch3,256)
#   switch_fault(switch2,257)
#   switch_fault(switch3,257)
#   switch_fault(switch2,258)
#   switch_fault(switch3,258)
#   switch_fault(switch2,259)
#   switch_fault(switch3,259)
#   switch_fault(switch2,260)
#   switch_fault(switch3,260)
#   switch_fault(switch2,261)
#   switch_fault(switch3,261)
#   switch_fault(switch2,262)
#   switch_fault(switch3,262)
#   switch_fault(switch2,263)
#   switch_fault(switch3,263)
#   switch_fault(switch2,264)
#   switch_fault(switch3,264)
#   switch_fault(switch2,265)
#   switch_fault(switch3,265)
#   switch_fault(switch2,266)
#   switch_fault(switch3,266)
#   switch_fault(switch2,267)
#   switch_fault(switch3,267)
#   switch_fault(switch2,268)
#   switch_fault(switch3,268)
#   switch_fault(switch2,269)
#   switch_fault(switch3,269)
#   switch_fault(switch2,270)
#   switch_fault(switch3,270)
#   switch_fault(switch2,271)
#   switch_fault(switch3,271)
#   switch_fault(switch2,272)
#   switch_fault(switch3,272)
#   switch_fault(switch2,273)
#   switch_fault(switch3,273)
#   switch_fault(switch2,274)
#   switch_fault(switch3,274)
#   switch_fault(switch2,275)
#   switch_fault(switch3,275)
#   switch_fault(switch2,276)
#   switch_fault(switch3,276)
#   switch_fault(switch2,277)
#   switch_fault(switch3,277)
#   switch_fault(switch2,278)
#   switch_fault(switch3,278)
#   switch_fault(switch2,279)
#   switch_fault(switch3,279)
#   switch_fault(switch2,280)
#   switch_fault(switch3,280)
#   switch_fault(switch2,281)
#   switch_fault(switch3,281)
#   switch_fault(switch2,282)
#   switch_fault(switch3,282)
#   switch_fault(switch2,283)
#   switch_fault(switch3,283)
#   switch_fault(switch2,284)
#   switch_fault(switch3,284)
#   switch_fault(switch2,285)
#   switch_fault(switch3,285)
#   switch_fault(switch2,286)
#   switch_fault(switch3,286)
#   switch_fault(switch2,287)
#   switch_fault(switch3,287)
#   switch_fault(switch2,288)
#   switch_fault(switch3,288)
#   switch_fault(switch2,289)
#   switch_fault(switch3,289)
#   switch_fault(switch2,290)
#   switch_fault(switch3,290)
#   switch_fault(switch2,291)
#   switch_fault(switch3,291)
#   switch_fault(switch2,292)
#   switch_fault(switch3,292)
#   switch_fault(switch2,293)
#   switch_fault(switch3,293)
#   switch_fault(switch2,294)
#   switch_fault(switch3,294)
#   switch_fault(switch2,295)
#   switch_fault(switch3,295)
#   switch_fault(switch2,296)
#   switch_fault(switch3,296)
#   switch_fault(switch2,297)
#   switch_fault(switch3,297)
#   switch_fault(switch2,298)
#   switch_fault(switch3,298)
#   switch_fault(switch2,299)
#   switch_fault(switch3,299)
#   switch_fault(switch2,300)
#   switch_fault(switch3,300)
#   switch_fault(switch2,301)
#   switch_fault(switch3,301)
#   switch_fault(switch2,302)
#   switch_fault(switch3,302)
#   switch_fault(switch2,303)
#   switch_fault(switch3,303)
#   switch_fault(switch2,304)
#   switch_fault(switch3,304)
#   switch_fault(switch2,305)
#   switch_fault(switch3,305)
#   switch_fault(switch2,306)
#   switch_fault(switch3,306)
#   switch_fault(switch2,307)
#   switch_fault(switch3,307)
#   switch_fault(switch2,308)
#   switch_fault(switch3,308)
#   switch_fault(switch2,309)
#   switch_fault(switch3,309)
#   switch_fault(switch2,310)
#   switch_fault(switch3,310)
#   switch_fault(switch2,311)
#   switch_fault(switch3,311)
#   switch_fault(switch2,312)
#   switch_fault(switch3,312)
#   switch_fault(switch2,313)
#   switch_fault(switch3,313)
#   switch_fault(switch2,314)
#   switch_fault(switch3,314)
#   switch_fault(switch2,315)
#   switch_fault(switch3,315)
#   switch_fault(switch2,316)
#   switch_fault(switch3,316)
#   switch_fault(switch2,317)
#   switch_fault(switch3,317)
#   switch_fault(switch2,318)
#   switch_fault(switch3,318)
#   switch_fault(switch2,319)
#   switch_fault(switch3,319)
#   switch_fault(switch2,320)
#   switch_fault(switch3,320)
#   switch_fault(switch2,321)
#   switch_fault(switch3,321)
#   switch_fault(switch2,322)
#   switch_fault(switch3,322)
#   switch_fault(switch2,323)
#   switch_fault(switch3,323)
#   switch_fault(switch2,324)
#   switch_fault(switch3,324)
#   switch_fault(switch2,325)
#   switch_fault(switch3,325)
#   switch_fault(switch2,326)
#   switch_fault(switch3,326)
#   switch_fault(switch2,327)
#   switch_fault(switch3,327)
#   switch_fault(switch2,328)
#   switch_fault(switch3,328)
#   switch_fault(switch2,329)
#   switch_fault(switch3,329)
#   switch_fault(switch2,330)
#   switch_fault(switch3,330)
#   switch_fault(switch2,331)
#   switch_fault(switch3,331)
#   switch_fault(switch2,332)
#   switch_fault(switch3,332)
#   switch_fault(switch2,333)
#   switch_fault(switch3,333)
#   switch_fault(switch2,334)
#   switch_fault(switch3,334)
#   switch_fault(switch2,335)
#   switch_fault(switch3,335)
#   switch_fault(switch2,336)
#   switch_fault(switch3,336)
#   switch_fault(switch2,337)
#   switch_fault(switch3,337)
#   switch_fault(switch2,338)
#   switch_fault(switch3,338)
#   switch_fault(switch2,339)
#   switch_fault(switch3,339)
#   switch_fault(switch2,340)
#   switch_fault(switch3,340)
#   switch_fault(switch2,341)
#   switch_fault(switch3,341)
#   switch_fault(switch2,342)
#   switch_fault(switch3,342)
#   switch_fault(switch2,343)
#   switch_fault(switch3,343)
#   switch_fault(switch2,344)
#   switch_fault(switch3,344)
#   switch_fault(switch2,345)
#   switch_fault(switch3,345)
#   switch_fault(switch2,346)
#   switch_fault(switch3,346)
#   switch_fault(switch2,347)
#   switch_fault(switch3,347)
#   switch_fault(switch2,348)
#   switch_fault(switch3,348)
#   switch_fault(switch2,349)
#   switch_fault(switch3,349)
#   switch_fault(switch2,350)
#   switch_fault(switch3,350)
#   switch_fault(switch2,351)
#   switch_fault(switch3,351)
#   switch_fault(switch2,352)
#   switch_fault(switch3,352)
#   switch_fault(switch2,353)
#   switch_fault(switch3,353)
#   switch_fault(switch2,354)
#   switch_fault(switch3,354)
#   switch_fault(switch2,355)
#   switch_fault(switch3,355)
#   switch_fault(switch2,356)
#   switch_fault(switch3,356)
#   switch_fault(switch2,357)
#   switch_fault(switch3,357)
#   switch_fault(switch2,358)
#   switch_fault(switch3,358)
#   switch_fault(switch2,359)
#   switch_fault(switch3,359)
#   switch_fault(switch2,360)
#   switch_fault(switch3,360)
#   switch_fault(switch2,361)
#   switch_fault(switch3,361)
#   switch_fault(switch2,362)
#   switch_fault(switch3,362)
#   switch_fault(switch2,363)
#   switch_fault(switch3,363)
#   switch_fault(switch2,364)
#   switch_fault(switch3,364)
#   switch_fault(switch2,365)
#   switch_fault(switch3,365)
#   switch_fault(switch2,366)
#   switch_fault(switch3,366)
#   switch_fault(switch2,367)
#   switch_fault(switch3,367)
#   switch_fault(switch2,368)
#   switch_fault(switch3,368)
#   switch_fault(switch2,369)
#   switch_fault(switch3,369)
#   switch_fault(switch2,370)
#   switch_fault(switch3,370)
#   switch_fault(switch2,371)
#   switch_fault(switch3,371)
#   switch_fault(switch2,372)
#   switch_fault(switch3,372)
#   switch_fault(switch2,373)
#   switch_fault(switch3,373)
#   switch_fault(switch2,374)
#   switch_fault(switch3,374)
#   switch_fault(switch2,375)
#   switch_fault(switch3,375)
#   switch_fault(switch2,376)
#   switch_fault(switch3,376)
#   switch_fault(switch2,377)
#   switch_fault(switch3,377)
#   switch_fault(switch2,378)
#   switch_fault(switch3,378)
#   switch_fault(switch2,379)
#   switch_fault(switch3,379)
#   switch_fault(switch2,380)
#   switch_fault(switch3,380)
#   switch_fault(switch2,381)
#   switch_fault(switch3,381)
#   switch_fault(switch2,382)
#   switch_fault(switch3,382)
#   switch_fault(switch2,383)
#   switch_fault(switch3,383)
#   switch_fault(switch2,384)
#   switch_fault(switch3,384)
#   switch_fault(switch2,385)
#   switch_fault(switch3,385)
#   switch_fault(switch2,386)
#   switch_fault(switch3,386)
#   switch_fault(switch2,387)
#   switch_fault(switch3,387)
#   switch_fault(switch2,388)
#   switch_fault(switch3,388)
#   switch_fault(switch2,389)
#   switch_fault(switch3,389)
#   switch_fault(switch2,390)
#   switch_fault(switch3,390)
#   switch_fault(switch2,391)
#   switch_fault(switch3,391)
#   switch_fault(switch2,392)
#   switch_fault(switch3,392)
#   switch_fault(switch2,393)
#   switch_fault(switch3,393)
#   switch_fault(switch2,394)
#   switch_fault(switch3,394)
#   switch_fault(switch2,395)
#   switch_fault(switch3,395)
#   switch_fault(switch2,396)
#   switch_fault(switch3,396)
#   switch_fault(switch2,397)
#   switch_fault(switch3,397)
#   switch_fault(switch2,398)
#   switch_fault(switch3,398)
#   switch_fault(switch2,399)
#   switch_fault(switch3,399)
#   switch_fault(switch2,400)
#   switch_fault(switch3,400)
#   switch_fault(switch2,401)
#   switch_fault(switch3,401)
#   switch_fault(switch2,402)
#   switch_fault(switch3,402)
#   switch_fault(switch2,403)
#   switch_fault(switch3,403)
#   switch_fault(switch2,404)
#   switch_fault(switch3,404)
#   switch_fault(switch2,405)
#   switch_fault(switch3,405)
#   switch_fault(switch2,406)
#   switch_fault(switch3,406)
#   switch_fault(switch2,407)
#   switch_fault(switch3,407)
#   switch_fault(switch2,408)
#   switch_fault(switch3,408)
#   switch_fault(switch2,409)
#   switch_fault(switch3,409)
#   switch_fault(switch2,410)
#   switch_fault(switch3,410)
#   switch_fault(switch2,411)
#   switch_fault(switch3,411)
#   switch_fault(switch2,412)
#   switch_fault(switch3,412)
#   switch_fault(switch2,413)
#   switch_fault(switch3,413)
#   switch_fault(switch2,414)
#   switch_fault(switch3,414)
#   switch_fault(switch2,415)
#   switch_fault(switch3,415)
#   switch_fault(switch2,416)
#   switch_fault(switch3,416)
#   switch_fault(switch2,417)
#   switch_fault(switch3,417)
#   switch_fault(switch2,418)
#   switch_fault(switch3,418)
#   switch_fault(switch2,419)
#   switch_fault(switch3,419)
#   switch_fault(switch2,420)
#   switch_fault(switch3,420)
#   switch_fault(switch2,421)
#   switch_fault(switch3,421)
#   switch_fault(switch2,422)
#   switch_fault(switch3,422)
#   switch_fault(switch2,423)
#   switch_fault(switch3,423)
#   switch_fault(switch2,424)
#   switch_fault(switch3,424)
#   switch_fault(switch2,425)
#   switch_fault(switch3,425)
#   switch_fault(switch2,426)
#   switch_fault(switch3,426)
#   switch_fault(switch2,427)
#   switch_fault(switch3,427)
#   switch_fault(switch2,428)
#   switch_fault(switch3,428)
#   switch_fault(switch2,429)
#   switch_fault(switch3,429)
#   switch_fault(switch2,430)
#   switch_fault(switch3,430)
#   switch_fault(switch2,431)
#   switch_fault(switch3,431)
#   switch_fault(switch2,432)
#   switch_fault(switch3,432)
#   switch_fault(switch2,433)
#   switch_fault(switch3,433)
#   switch_fault(switch2,434)
#   switch_fault(switch3,434)
#   switch_fault(switch2,435)
#   switch_fault(switch3,435)
#   switch_fault(switch2,436)
#   switch_fault(switch3,436)
#   switch_fault(switch2,437)
#   switch_fault(switch3,437)
#   switch_fault(switch2,438)
#   switch_fault(switch3,438)
#   switch_fault(switch2,439)
#   switch_fault(switch3,439)
#   switch_fault(switch2,440)
#   switch_fault(switch3,440)
#   switch_fault(switch2,441)
#   switch_fault(switch3,441)
#   switch_fault(switch2,442)
#   switch_fault(switch3,442)
#   switch_fault(switch2,443)
#   switch_fault(switch3,443)
#   switch_fault(switch2,444)
#   switch_fault(switch3,444)
#   switch_fault(switch2,445)
#   switch_fault(switch3,445)
#   switch_fault(switch2,446)
#   switch_fault(switch3,446)
#   switch_fault(switch2,447)
#   switch_fault(switch3,447)
#   switch_fault(switch2,448)
#   switch_fault(switch3,448)
#   switch_fault(switch2,449)
#   switch_fault(switch3,449)
#   switch_fault(switch2,450)
#   switch_fault(switch3,450)
#   switch_fault(switch2,451)
#   switch_fault(switch3,451)
#   switch_fault(switch2,452)
#   switch_fault(switch3,452)
#   switch_fault(switch2,453)
#   switch_fault(switch3,453)
#   switch_fault(switch2,454)
#   switch_fault(switch3,454)
#   switch_fault(switch2,455)
#   switch_fault(switch3,455)
#   switch_fault(switch2,456)
#   switch_fault(switch3,456)
#   switch_fault(switch2,457)
#   switch_fault(switch3,457)
#   switch_fault(switch2,458)
#   switch_fault(switch3,458)
#   switch_fault(switch2,459)
#   switch_fault(switch3,459)
#   switch_fault(switch2,460)
#   switch_fault(switch3,460)
#   switch_fault(switch2,461)
#   switch_fault(switch3,461)
#   switch_fault(switch2,462)
#   switch_fault(switch3,462)
#   switch_fault(switch2,463)
#   switch_fault(switch3,463)
#   switch_fault(switch2,464)
#   switch_fault(switch3,464)
#   switch_fault(switch2,465)
#   switch_fault(switch3,465)
#   switch_fault(switch2,466)
#   switch_fault(switch3,466)
#   switch_fault(switch2,467)
#   switch_fault(switch3,467)
#   switch_fault(switch2,468)
#   switch_fault(switch3,468)
#   switch_fault(switch2,469)
#   switch_fault(switch3,469)
#   switch_fault(switch2,470)
#   switch_fault(switch3,470)
#   switch_fault(switch2,471)
#   switch_fault(switch3,471)
#   switch_fault(switch2,472)
#   switch_fault(switch3,472)
#   switch_fault(switch2,473)
#   switch_fault(switch3,473)
#   switch_fault(switch2,474)
#   switch_fault(switch3,474)
#   switch_fault(switch2,475)
#   switch_fault(switch3,475)
#   switch_fault(switch2,476)
#   switch_fault(switch3,476)
#   switch_fault(switch2,477)
#   switch_fault(switch3,477)
#   switch_fault(switch2,478)
#   switch_fault(switch3,478)
#   switch_fault(switch2,479)
#   switch_fault(switch3,479)
#   switch_fault(switch2,480)
#   switch_fault(switch3,480)
#   switch_fault(switch2,481)
#   switch_fault(switch3,481)
#   switch_fault(switch2,482)
#   switch_fault(switch3,482)
#   switch_fault(switch2,483)
#   switch_fault(switch3,483)
#   switch_fault(switch2,484)
#   switch_fault(switch3,484)
#   switch_fault(switch2,485)
#   switch_fault(switch3,485)
#   switch_fault(switch2,486)
#   switch_fault(switch3,486)
#   switch_fault(switch2,487)
#   switch_fault(switch3,487)
#   switch_fault(switch2,488)
#   switch_fault(switch3,488)
#   switch_fault(switch2,489)
#   switch_fault(switch3,489)
#   switch_fault(switch2,490)
#   switch_fault(switch3,490)
#   switch_fault(switch2,491)
#   switch_fault(switch3,491)
#   switch_fault(switch2,492)
#   switch_fault(switch3,492)
#   switch_fault(switch2,493)
#   switch_fault(switch3,493)
#   switch_fault(switch2,494)
#   switch_fault(switch3,494)
#   switch_fault(switch2,495)
#   switch_fault(switch3,495)
#   switch_fault(switch2,496)
#   switch_fault(switch3,496)
#   switch_fault(switch2,497)
#   switch_fault(switch3,497)
#   switch_fault(switch2,498)
#   switch_fault(switch3,498)
#   switch_fault(switch2,499)
#   switch_fault(switch3,499)
#   switch_fault(switch2,500)
#   switch_fault(switch3,500)
#   switch_fault(switch2,501)
#   switch_fault(switch3,501)
#   switch_fault(switch2,502)
#   switch_fault(switch3,502)
#   switch_fault(switch2,503)
#   switch_fault(switch3,503)
#   switch_fault(switch2,504)
#   switch_fault(switch3,504)
#   switch_fault(switch2,505)
#   switch_fault(switch3,505)
#   switch_fault(switch2,506)
#   switch_fault(switch3,506)
#   switch_fault(switch2,507)
#   switch_fault(switch3,507)
#   switch_fault(switch2,508)
#   switch_fault(switch3,508)
#   switch_fault(switch2,509)
#   switch_fault(switch3,509)
#   switch_fault(switch2,510)
#   switch_fault(switch3,510)
#   switch_fault(switch2,511)
#   switch_fault(switch3,511)
#   switch_fault(switch2,512)
#   switch_fault(switch3,512)
#   switch_fault(switch2,513)
#   switch_fault(switch3,513)
#   switch_fault(switch2,514)
#   switch_fault(switch3,514)
#   switch_fault(switch2,515)
#   switch_fault(switch3,515)
#   switch_fault(switch2,516)
#   switch_fault(switch3,516)
#   switch_fault(switch2,517)
#   switch_fault(switch3,517)
#   switch_fault(switch2,518)
#   switch_fault(switch3,518)
#   switch_fault(switch2,519)
#   switch_fault(switch3,519)
#   switch_fault(switch2,520)
#   switch_fault(switch3,520)
#   switch_fault(switch2,521)
#   switch_fault(switch3,521)
#   switch_fault(switch2,522)
#   switch_fault(switch3,522)
#   switch_fault(switch2,523)
#   switch_fault(switch3,523)
#   switch_fault(switch2,524)
#   switch_fault(switch3,524)
#   switch_fault(switch2,525)
#   switch_fault(switch3,525)
#   switch_fault(switch2,526)
#   switch_fault(switch3,526)
#   switch_fault(switch2,527)
#   switch_fault(switch3,527)
#   switch_fault(switch2,528)
#   switch_fault(switch3,528)
#   switch_fault(switch2,529)
#   switch_fault(switch3,529)
#   switch_fault(switch2,530)
#   switch_fault(switch3,530)
#   switch_fault(switch2,531)
#   switch_fault(switch3,531)
#   switch_fault(switch2,532)
#   switch_fault(switch3,532)
#   switch_fault(switch2,533)
#   switch_fault(switch3,533)
#   switch_fault(switch2,534)
#   switch_fault(switch3,534)
#   switch_fault(switch2,535)
#   switch_fault(switch3,535)
#   switch_fault(switch2,536)
#   switch_fault(switch3,536)
#   switch_fault(switch2,537)
#   switch_fault(switch3,537)
#   switch_fault(switch2,538)
#   switch_fault(switch3,538)
#   switch_fault(switch2,539)
#   switch_fault(switch3,539)
#   switch_fault(switch2,540)
#   switch_fault(switch3,540)
#   switch_fault(switch2,541)
#   switch_fault(switch3,541)
#   switch_fault(switch2,542)
#   switch_fault(switch3,542)
#   switch_fault(switch2,543)
#   switch_fault(switch3,543)
#   switch_fault(switch2,544)
#   switch_fault(switch3,544)
#   switch_fault(switch2,545)
#   switch_fault(switch3,545)
#   switch_fault(switch2,546)
#   switch_fault(switch3,546)
#   switch_fault(switch2,547)
#   switch_fault(switch3,547)
#   switch_fault(switch2,548)
#   switch_fault(switch3,548)
#   switch_fault(switch2,549)
#   switch_fault(switch3,549)
#   switch_fault(switch2,550)
#   switch_fault(switch3,550)
#   switch_fault(switch2,551)
#   switch_fault(switch3,551)
#   switch_fault(switch2,552)
#   switch_fault(switch3,552)
#   switch_fault(switch2,553)
#   switch_fault(switch3,553)
#   switch_fault(switch2,554)
#   switch_fault(switch3,554)
#   switch_fault(switch2,555)
#   switch_fault(switch3,555)
#   switch_fault(switch2,556)
#   switch_fault(switch3,556)
#   switch_fault(switch2,557)
#   switch_fault(switch3,557)
#   switch_fault(switch2,558)
#   switch_fault(switch3,558)
#   switch_fault(switch2,559)
#   switch_fault(switch3,559)
#   switch_fault(switch2,560)
#   switch_fault(switch3,560)
#   switch_fault(switch2,561)
#   switch_fault(switch3,561)
#   switch_fault(switch2,562)
#   switch_fault(switch3,562)
#   switch_fault(switch2,563)
#   switch_fault(switch3,563)
#   switch_fault(switch2,564)
#   switch_fault(switch3,564)
#   switch_fault(switch2,565)
#   switch_fault(switch3,565)
#   switch_fault(switch2,566)
#   switch_fault(switch3,566)
#   switch_fault(switch2,567)
#   switch_fault(switch3,567)
#   switch_fault(switch2,568)
#   switch_fault(switch3,568)
#   switch_fault(switch2,569)
#   switch_fault(switch3,569)
#   switch_fault(switch2,570)
#   switch_fault(switch3,570)
#   switch_fault(switch2,571)
#   switch_fault(switch3,571)
#   switch_fault(switch2,572)
#   switch_fault(switch3,572)
#   switch_fault(switch2,573)
#   switch_fault(switch3,573)
#   switch_fault(switch2,574)
#   switch_fault(switch3,574)
#   switch_fault(switch2,575)
#   switch_fault(switch3,575)
#   switch_fault(switch2,576)
#   switch_fault(switch3,576)
#   switch_fault(switch2,577)
#   switch_fault(switch3,577)
#   switch_fault(switch2,578)
#   switch_fault(switch3,578)
#   switch_fault(switch2,579)
#   switch_fault(switch3,579)
#   switch_fault(switch2,580)
#   switch_fault(switch3,580)
#   switch_fault(switch2,581)
#   switch_fault(switch3,581)
#   switch_fault(switch2,582)
#   switch_fault(switch3,582)
#   switch_fault(switch2,583)
#   switch_fault(switch3,583)
#   switch_fault(switch2,584)
#   switch_fault(switch3,584)
#   switch_fault(switch2,585)
#   switch_fault(switch3,585)
#   switch_fault(switch2,586)
#   switch_fault(switch3,586)
#   switch_fault(switch2,587)
#   switch_fault(switch3,587)
#   switch_fault(switch2,588)
#   switch_fault(switch3,588)
#   switch_fault(switch2,589)
#   switch_fault(switch3,589)
#   switch_fault(switch2,590)
#   switch_fault(switch3,590)
#   switch_fault(switch2,591)
#   switch_fault(switch3,591)
#   switch_fault(switch2,592)
#   switch_fault(switch3,592)
#   switch_fault(switch2,593)
#   switch_fault(switch3,593)
#   switch_fault(switch2,594)
#   switch_fault(switch3,594)
#   switch_fault(switch2,595)
#   switch_fault(switch3,595)
#   switch_fault(switch2,596)
#   switch_fault(switch3,596)
#   switch_fault(switch2,597)
#   switch_fault(switch3,597)
#   switch_fault(switch2,598)
#   switch_fault(switch3,598)
#   switch_fault(switch2,599)
#   switch_fault(switch3,599)
#   switch_fault(switch2,600)
#   switch_fault(switch3,600)
#   switch_fault(switch2,601)
#   switch_fault(switch3,601)
#   switch_fault(switch2,602)
#   switch_fault(switch3,602)
#   switch_fault(switch2,603)
#   switch_fault(switch3,603)
#   switch_fault(switch2,604)
#   switch_fault(switch3,604)
#   switch_fault(switch2,605)
#   switch_fault(switch3,605)
#   switch_fault(switch2,606)
#   switch_fault(switch3,606)
#   switch_fault(switch2,607)
#   switch_fault(switch3,607)
#   switch_fault(switch2,608)
#   switch_fault(switch3,608)
#   switch_fault(switch2,609)
#   switch_fault(switch3,609)
#   switch_fault(switch2,610)
#   switch_fault(switch3,610)
#   switch_fault(switch2,611)
#   switch_fault(switch3,611)
#   switch_fault(switch2,612)
#   switch_fault(switch3,612)
#   switch_fault(switch2,613)
#   switch_fault(switch3,613)
#   switch_fault(switch2,614)
#   switch_fault(switch3,614)
#   switch_fault(switch2,615)
#   switch_fault(switch3,615)
#   switch_fault(switch2,616)
#   switch_fault(switch3,616)
#   switch_fault(switch2,617)
#   switch_fault(switch3,617)
#   switch_fault(switch2,618)
#   switch_fault(switch3,618)
#   switch_fault(switch2,619)
#   switch_fault(switch3,619)
#   switch_fault(switch2,620)
#   switch_fault(switch3,620)
#   switch_fault(switch2,621)
#   switch_fault(switch3,621)
#   switch_fault(switch2,622)
#   switch_fault(switch3,622)
#   switch_fault(switch2,623)
#   switch_fault(switch3,623)
#   switch_fault(switch2,624)
#   switch_fault(switch3,624)
#   switch_fault(switch2,625)
#   switch_fault(switch3,625)
#   switch_fault(switch2,626)
#   switch_fault(switch3,626)
#   switch_fault(switch2,627)
#   switch_fault(switch3,627)
#   switch_fault(switch2,628)
#   switch_fault(switch3,628)
#   switch_fault(switch2,629)
#   switch_fault(switch3,629)
#   switch_fault(switch2,630)
#   switch_fault(switch3,630)
#   switch_fault(switch2,631)
#   switch_fault(switch3,631)
#   switch_fault(switch2,632)
#   switch_fault(switch3,632)
#   switch_fault(switch2,633)
#   switch_fault(switch3,633)
#   switch_fault(switch2,634)
#   switch_fault(switch3,634)
#   switch_fault(switch2,635)
#   switch_fault(switch3,635)
#   switch_fault(switch2,636)
#   switch_fault(switch3,636)
#   switch_fault(switch2,637)
#   switch_fault(switch3,637)
#   switch_fault(switch2,638)
#   switch_fault(switch3,638)
#   switch_fault(switch2,639)
#   switch_fault(switch3,639)
#   switch_fault(switch2,640)
#   switch_fault(switch3,640)
#   switch_fault(switch2,641)
#   switch_fault(switch3,641)
#   switch_fault(switch2,642)
#   switch_fault(switch3,642)
#   switch_fault(switch2,643)
#   switch_fault(switch3,643)
#   switch_fault(switch2,644)
#   switch_fault(switch3,644)
#   switch_fault(switch2,645)
#   switch_fault(switch3,645)
#   switch_fault(switch2,646)
#   switch_fault(switch3,646)
#   switch_fault(switch2,647)
#   switch_fault(switch3,647)
#   switch_fault(switch2,648)
#   switch_fault(switch3,648)
#   switch_fault(switch2,649)
#   switch_fault(switch3,649)
#   switch_fault(switch2,650)
#   switch_fault(switch3,650)
#   switch_fault(switch2,651)
#   switch_fault(switch3,651)
#   switch_fault(switch2,652)
#   switch_fault(switch3,652)
#   switch_fault(switch2,653)
#   switch_fault(switch3,653)
#   switch_fault(switch2,654)
#   switch_fault(switch3,654)
#   switch_fault(switch2,655)
#   switch_fault(switch3,655)
#   switch_fault(switch2,656)
#   switch_fault(switch3,656)
#   switch_fault(switch2,657)
#   switch_fault(switch3,657)
#   switch_fault(switch2,658)
#   switch_fault(switch3,658)
#   switch_fault(switch2,659)
#   switch_fault(switch3,659)
#   switch_fault(switch2,660)
#   switch_fault(switch3,660)
#   switch_fault(switch2,661)
#   switch_fault(switch3,661)
#   switch_fault(switch2,662)
#   switch_fault(switch3,662)
#   switch_fault(switch2,663)
#   switch_fault(switch3,663)
#   switch_fault(switch2,664)
#   switch_fault(switch3,664)
#   switch_fault(switch2,665)
#   switch_fault(switch3,665)
#   switch_fault(switch2,666)
#   switch_fault(switch3,666)
#   switch_fault(switch2,667)
#   switch_fault(switch3,667)
#   switch_fault(switch2,668)
#   switch_fault(switch3,668)
#   switch_fault(switch2,669)
#   switch_fault(switch3,669)
#   switch_fault(switch2,670)
#   switch_fault(switch3,670)
#   switch_fault(switch2,671)
#   switch_fault(switch3,671)
#   switch_fault(switch2,672)
#   switch_fault(switch3,672)
#   switch_fault(switch2,673)
#   switch_fault(switch3,673)
#   switch_fault(switch2,674)
#   switch_fault(switch3,674)
#   switch_fault(switch2,675)
#   switch_fault(switch3,675)
#   switch_fault(switch2,676)
#   switch_fault(switch3,676)
#   switch_fault(switch2,677)
#   switch_fault(switch3,677)
#   switch_fault(switch2,678)
#   switch_fault(switch3,678)
#   switch_fault(switch2,679)
#   switch_fault(switch3,679)
#   switch_fault(switch2,680)
#   switch_fault(switch3,680)
#   switch_fault(switch2,681)
#   switch_fault(switch3,681)
#   switch_fault(switch2,682)
#   switch_fault(switch3,682)
#   switch_fault(switch2,683)
#   switch_fault(switch3,683)
#   switch_fault(switch2,684)
#   switch_fault(switch3,684)
#   switch_fault(switch2,685)
#   switch_fault(switch3,685)
#   switch_fault(switch2,686)
#   switch_fault(switch3,686)
#   switch_fault(switch2,687)
#   switch_fault(switch3,687)
#   switch_fault(switch2,688)
#   switch_fault(switch3,688)
#   switch_fault(switch2,689)
#   switch_fault(switch3,689)
#   switch_fault(switch2,690)
#   switch_fault(switch3,690)
#   switch_fault(switch2,691)
#   switch_fault(switch3,691)
#   switch_fault(switch2,692)
#   switch_fault(switch3,692)
#   switch_fault(switch2,693)
#   switch_fault(switch3,693)
#   switch_fault(switch2,694)
#   switch_fault(switch3,694)
#   switch_fault(switch2,695)
#   switch_fault(switch3,695)
#   switch_fault(switch2,696)
#   switch_fault(switch3,696)
#   switch_fault(switch2,697)
#   switch_fault(switch3,697)
#   switch_fault(switch2,698)
#   switch_fault(switch3,698)
#   switch_fault(switch2,699)
#   switch_fault(switch3,699)
#   switch_fault(switch2,700)
#   switch_fault(switch3,700)
#   switch_fault(switch2,701)
#   switch_fault(switch3,701)
#   switch_fault(switch2,702)
#   switch_fault(switch3,702)
#   switch_fault(switch2,703)
#   switch_fault(switch3,703)
#   switch_fault(switch2,704)
#   switch_fault(switch3,704)
#   switch_fault(switch2,705)
#   switch_fault(switch3,705)
#   switch_fault(switch2,706)
#   switch_fault(switch3,706)
#   switch_fault(switch2,707)
#   switch_fault(switch3,707)
#   switch_fault(switch2,708)
#   switch_fault(switch3,708)
#   switch_fault(switch2,709)
#   switch_fault(switch3,709)
#   switch_fault(switch2,710)
#   switch_fault(switch3,710)
#   switch_fault(switch2,711)
#   switch_fault(switch3,711)
#   switch_fault(switch2,712)
#   switch_fault(switch3,712)
#   switch_fault(switch2,713)
#   switch_fault(switch3,713)
#   switch_fault(switch2,714)
#   switch_fault(switch3,714)
#   switch_fault(switch2,715)
#   switch_fault(switch3,715)
#   switch_fault(switch2,716)
#   switch_fault(switch3,716)
#   switch_fault(switch2,717)
#   switch_fault(switch3,717)
#   switch_fault(switch2,718)
#   switch_fault(switch3,718)
#   switch_fault(switch2,719)
#   switch_fault(switch3,719)
#   switch_fault(switch2,720)
#   switch_fault(switch3,720)
#   switch_fault(switch2,721)
#   switch_fault(switch3,721)
#   switch_fault(switch2,722)
#   switch_fault(switch3,722)
#   switch_fault(switch2,723)
#   switch_fault(switch3,723)
#   switch_fault(switch2,724)
#   switch_fault(switch3,724)
#   switch_fault(switch2,725)
#   switch_fault(switch3,725)
#   switch_fault(switch2,726)
#   switch_fault(switch3,726)
#   switch_fault(switch2,727)
#   switch_fault(switch3,727)
#   switch_fault(switch2,728)
#   switch_fault(switch3,728)
#   switch_fault(switch2,729)
#   switch_fault(switch3,729)
#   switch_fault(switch2,730)
#   switch_fault(switch3,730)
#   switch_fault(switch2,731)
#   switch_fault(switch3,731)
#   switch_fault(switch2,732)
#   switch_fault(switch3,732)
#   switch_fault(switch2,733)
#   switch_fault(switch3,733)
#   switch_fault(switch2,734)
#   switch_fault(switch3,734)
#   switch_fault(switch2,735)
#   switch_fault(switch3,735)
#   switch_fault(switch2,736)
#   switch_fault(switch3,736)
#   switch_fault(switch2,737)
#   switch_fault(switch3,737)
#   switch_fault(switch2,738)
#   switch_fault(switch3,738)
#   switch_fault(switch2,739)
#   switch_fault(switch3,739)
#   switch_fault(switch2,740)
#   switch_fault(switch3,740)
#   switch_fault(switch2,741)
#   switch_fault(switch3,741)
#   switch_fault(switch2,742)
#   switch_fault(switch3,742)
#   switch_fault(switch2,743)
#   switch_fault(switch3,743)
#   switch_fault(switch2,744)
#   switch_fault(switch3,744)
#   switch_fault(switch2,745)
#   switch_fault(switch3,745)
#   switch_fault(switch2,746)
#   switch_fault(switch3,746)
#   switch_fault(switch2,747)
#   switch_fault(switch3,747)
#   switch_fault(switch2,748)
#   switch_fault(switch3,748)
#   switch_fault(switch2,749)
#   switch_fault(switch3,749)
#   switch_fault(switch2,750)
#   switch_fault(switch3,750)
#   switch_fault(switch2,751)
#   switch_fault(switch3,751)
#   switch_fault(switch2,752)
#   switch_fault(switch3,752)
#   switch_fault(switch2,753)
#   switch_fault(switch3,753)
#   switch_fault(switch2,754)
#   switch_fault(switch3,754)
#   switch_fault(switch2,755)
#   switch_fault(switch3,755)
#   switch_fault(switch2,756)
#   switch_fault(switch3,756)
#   switch_fault(switch2,757)
#   switch_fault(switch3,757)
#   switch_fault(switch2,758)
#   switch_fault(switch3,758)
#   switch_fault(switch2,759)
#   switch_fault(switch3,759)
#   switch_fault(switch2,760)
#   switch_fault(switch3,760)
#   switch_fault(switch2,761)
#   switch_fault(switch3,761)
#   switch_fault(switch2,762)
#   switch_fault(switch3,762)
#   switch_fault(switch2,763)
#   switch_fault(switch3,763)
#   switch_fault(switch2,764)
#   switch_fault(switch3,764)
#   switch_fault(switch2,765)
#   switch_fault(switch3,765)
#   switch_fault(switch2,766)
#   switch_fault(switch3,766)
#   switch_fault(switch2,767)
#   switch_fault(switch3,767)
#   switch_fault(switch2,768)
#   switch_fault(switch3,768)
#   switch_fault(switch2,769)
#   switch_fault(switch3,769)
#   switch_fault(switch2,770)
#   switch_fault(switch3,770)
#   switch_fault(switch2,771)
#   switch_fault(switch3,771)
#   switch_fault(switch2,772)
#   switch_fault(switch3,772)
#   switch_fault(switch2,773)
#   switch_fault(switch3,773)
#   switch_fault(switch2,774)
#   switch_fault(switch3,774)
#   switch_fault(switch2,775)
#   switch_fault(switch3,775)
#   switch_fault(switch2,776)
#   switch_fault(switch3,776)
#   switch_fault(switch2,777)
#   switch_fault(switch3,777)
#   switch_fault(switch2,778)
#   switch_fault(switch3,778)
#   switch_fault(switch2,779)
#   switch_fault(switch3,779)
#   switch_fault(switch2,780)
#   switch_fault(switch3,780)
#   switch_fault(switch2,781)
#   switch_fault(switch3,781)
#   switch_fault(switch2,782)
#   switch_fault(switch3,782)
#   switch_fault(switch2,783)
#   switch_fault(switch3,783)
#   switch_fault(switch2,784)
#   switch_fault(switch3,784)
#   switch_fault(switch2,785)
#   switch_fault(switch3,785)
#   switch_fault(switch2,786)
#   switch_fault(switch3,786)
#   switch_fault(switch2,787)
#   switch_fault(switch3,787)
#   switch_fault(switch2,788)
#   switch_fault(switch3,788)
#   switch_fault(switch2,789)
#   switch_fault(switch3,789)
#   switch_fault(switch2,790)
#   switch_fault(switch3,790)
#   switch_fault(switch2,791)
#   switch_fault(switch3,791)
#   switch_fault(switch2,792)
#   switch_fault(switch3,792)
#   switch_fault(switch2,793)
#   switch_fault(switch3,793)
#   switch_fault(switch2,794)
#   switch_fault(switch3,794)
#   switch_fault(switch2,795)
#   switch_fault(switch3,795)
#   switch_fault(switch2,796)
#   switch_fault(switch3,796)
#   switch_fault(switch2,797)
#   switch_fault(switch3,797)
#   switch_fault(switch2,798)
#   switch_fault(switch3,798)
#   switch_fault(switch2,799)
#   switch_fault(switch3,799)
#   switch_fault(switch2,800)
#   switch_fault(switch3,800)
#   switch_fault(switch2,801)
#   switch_fault(switch3,801)
#   switch_fault(switch2,802)
#   switch_fault(switch3,802)
#   switch_fault(switch2,803)
#   switch_fault(switch3,803)
#   switch_fault(switch2,804)
#   switch_fault(switch3,804)
#   switch_fault(switch2,805)
#   switch_fault(switch3,805)
#   switch_fault(switch2,806)
#   switch_fault(switch3,806)
#   switch_fault(switch2,807)
#   switch_fault(switch3,807)
#   switch_fault(switch2,808)
#   switch_fault(switch3,808)
#   switch_fault(switch2,809)
#   switch_fault(switch3,809)
#   switch_fault(switch2,810)
#   switch_fault(switch3,810)
#   switch_fault(switch2,811)
#   switch_fault(switch3,811)
#   switch_fault(switch2,812)
#   switch_fault(switch3,812)
#   switch_fault(switch2,813)
#   switch_fault(switch3,813)
#   switch_fault(switch2,814)
#   switch_fault(switch3,814)
#   switch_fault(switch2,815)
#   switch_fault(switch3,815)
#   switch_fault(switch2,816)
#   switch_fault(switch3,816)
#   switch_fault(switch2,817)
#   switch_fault(switch3,817)
#   switch_fault(switch2,818)
#   switch_fault(switch3,818)
#   switch_fault(switch2,819)
#   switch_fault(switch3,819)
#   switch_fault(switch2,820)
#   switch_fault(switch3,820)
#   switch_fault(switch2,821)
#   switch_fault(switch3,821)
#   switch_fault(switch2,822)
#   switch_fault(switch3,822)
#   switch_fault(switch2,823)
#   switch_fault(switch3,823)
#   switch_fault(switch2,824)
#   switch_fault(switch3,824)
#   switch_fault(switch2,825)
#   switch_fault(switch3,825)
#   switch_fault(switch2,826)
#   switch_fault(switch3,826)
#   switch_fault(switch2,827)
#   switch_fault(switch3,827)
#   switch_fault(switch2,828)
#   switch_fault(switch3,828)
#   switch_fault(switch2,829)
#   switch_fault(switch3,829)
#   switch_fault(switch2,830)
#   switch_fault(switch3,830)
#   switch_fault(switch2,831)
#   switch_fault(switch3,831)
#   switch_fault(switch2,832)
#   switch_fault(switch3,832)
#   switch_fault(switch2,833)
#   switch_fault(switch3,833)
#   switch_fault(switch2,834)
#   switch_fault(switch3,834)
#   switch_fault(switch2,835)
#   switch_fault(switch3,835)
#   switch_fault(switch2,836)
#   switch_fault(switch3,836)
#   switch_fault(switch2,837)
#   switch_fault(switch3,837)
#   switch_fault(switch2,838)
#   switch_fault(switch3,838)
#   switch_fault(switch2,839)
#   switch_fault(switch3,839)
#   switch_fault(switch2,840)
#   switch_fault(switch3,840)
#   switch_fault(switch2,841)
#   switch_fault(switch3,841)
#   switch_fault(switch2,842)
#   switch_fault(switch3,842)
#   switch_fault(switch2,843)
#   switch_fault(switch3,843)
#   switch_fault(switch2,844)
#   switch_fault(switch3,844)
#   switch_fault(switch2,845)
#   switch_fault(switch3,845)
#   switch_fault(switch2,846)
#   switch_fault(switch3,846)
#   switch_fault(switch2,847)
#   switch_fault(switch3,847)
#   switch_fault(switch2,848)
#   switch_fault(switch3,848)
#   switch_fault(switch2,849)
#   switch_fault(switch3,849)
#   switch_fault(switch2,850)
#   switch_fault(switch3,850)
#   switch_fault(switch2,851)
#   switch_fault(switch3,851)
#   switch_fault(switch2,852)
#   switch_fault(switch3,852)
#   switch_fault(switch2,853)
#   switch_fault(switch3,853)
#   switch_fault(switch2,854)
#   switch_fault(switch3,854)
#   switch_fault(switch2,855)
#   switch_fault(switch3,855)
#   switch_fault(switch2,856)
# ...
#   switch_fault(switch3,17475)
#   switch_fault(switch3,17476)
#   switch_fault(switch3,17477)
#   switch_fault(switch3,17478)
#   switch_fault(switch3,17479)
#   switch_fault(switch3,17480)
#   switch_fault(switch3,17481)
#   switch_fault(switch3,17482)
#   switch_fault(switch3,17483)
#   switch_fault(switch3,17484)
#   switch_fault(switch3,17485)
#   switch_fault(switch3,17486)
#   switch_fault(switch3,17487)
#   switch_fault(switch3,17488)
#   switch_fault(switch3,17489)
#   switch_fault(switch3,17490)
#   switch_fault(switch3,17491)
#   switch_fault(switch3,17492)
#   switch_fault(switch3,17493)
#   switch_fault(switch3,17494)
#   switch_fault(switch3,17495)
#   switch_fault(switch3,17496)
#   switch_fault(switch3,17497)
#   switch_fault(switch3,17498)
#   switch_fault(switch3,17499)
#   switch_fault(switch3,17500)
#   switch_fault(switch3,17501)
#   switch_fault(switch3,17502)
#   switch_fault(switch3,17503)
#   switch_fault(switch3,17504)
#   switch_fault(switch3,17505)
#   switch_fault(switch3,17506)
#   switch_fault(switch3,17507)
#   switch_fault(switch3,17508)
#   switch_fault(switch3,17509)
#   switch_fault(switch3,17510)
#   switch_fault(switch3,17511)
#   switch_fault(switch3,17512)
#   switch_fault(switch3,17513)
#   switch_fault(switch3,17514)
#   switch_fault(switch3,17515)
#   switch_fault(switch3,17516)
#   switch_fault(switch3,17517)
#   switch_fault(switch3,17518)
#   switch_fault(switch3,17519)
#   switch_fault(switch3,17520)
#   switch_fault(switch3,17521)
#   switch_fault(switch3,17522)
#   switch_fault(switch3,17523)
#   switch_fault(switch3,17524)
#   switch_fault(switch3,17525)
#   switch_fault(switch3,17526)
#   switch_fault(switch3,17527)
#   switch_fault(switch3,17528)
#   switch_fault(switch3,17529)
#   switch_fault(switch3,17530)
#   switch_fault(switch3,17531)
#   switch_fault(switch3,17532)
#   switch_fault(switch3,17533)
#   switch_fault(switch3,17534)
#   switch_fault(switch3,17535)
#   switch_fault(switch3,17536)
#   switch_fault(switch3,17537)
#   switch_fault(switch3,17538)
#   switch_fault(switch3,17539)
#   switch_fault(switch3,17540)
#   switch_fault(switch3,17541)
#   switch_fault(switch3,17542)
#   switch_fault(switch3,17543)
#   switch_fault(switch3,17544)
#   switch_fault(switch3,17545)
#   switch_fault(switch3,17546)
#   switch_fault(switch3,17547)
#   switch_fault(switch3,17548)
#   switch_fault(switch3,17549)
#   switch_fault(switch3,17550)
#   switch_fault(switch3,17551)
#   switch_fault(switch3,17552)
#   switch_fault(switch3,17553)
#   switch_fault(switch3,17554)
#   switch_fault(switch3,17555)
#   switch_fault(switch3,17556)
#   switch_fault(switch3,17557)
#   switch_fault(switch3,17558)
#   switch_fault(switch3,17559)
#   switch_fault(switch3,17560)
#   switch_fault(switch3,17561)
#   switch_fault(switch3,17562)
#   switch_fault(switch3,17563)
#   switch_fault(switch3,17564)
#   switch_fault(switch3,17565)
#   switch_fault(switch3,17566)
#   switch_fault(switch3,17567)
#   switch_fault(switch3,17568)
#   switch_fault(switch3,17569)
#   switch_fault(switch3,17570)
#   switch_fault(switch3,17571)
#   switch_fault(switch3,17572)
#   switch_fault(switch3,17573)
#   switch_fault(switch3,17574)
#   switch_fault(switch3,17575)
#   switch_fault(switch3,17576)
#   switch_fault(switch3,17577)
#   switch_fault(switch3,17578)
#   switch_fault(switch3,17579)
#   switch_fault(switch3,17580)
#   switch_fault(switch3,17581)
#   switch_fault(switch3,17582)
#   switch_fault(switch3,17583)
#   switch_fault(switch3,17584)
#   switch_fault(switch3,17585)
#   switch_fault(switch3,17586)
#   switch_fault(switch3,17587)
#   switch_fault(switch3,17588)
#   switch_fault(switch3,17589)
#   switch_fault(switch3,17590)
#   switch_fault(switch3,17591)
#   switch_fault(switch3,17592)
#   switch_fault(switch3,17593)
#   switch_fault(switch3,17594)
#   switch_fault(switch3,17595)
#   switch_fault(switch3,17596)
#   switch_fault(switch3,17597)
#   switch_fault(switch3,17598)
#   switch_fault(switch3,17599)
#   switch_fault(switch3,17600)
#   switch_fault(switch3,17601)
#   switch_fault(switch3,17602)
#   switch_fault(switch3,17603)
#   switch_fault(switch3,17604)
#   switch_fault(switch3,17605)
#   switch_fault(switch3,17606)
#   switch_fault(switch3,17607)
#   switch_fault(switch3,17608)
#   switch_fault(switch3,17609)
#   switch_fault(switch3,17610)
#   switch_fault(switch3,17611)
#   switch_fault(switch3,17612)
#   switch_fault(switch3,17613)
#   switch_fault(switch3,17614)
#   switch_fault(switch3,17615)
#   switch_fault(switch3,17616)
#   switch_fault(switch3,17617)
#   switch_fault(switch3,17618)
#   switch_fault(switch3,17619)
#   switch_fault(switch3,17620)
#   switch_fault(switch3,17621)
#   switch_fault(switch3,17622)
#   switch_fault(switch3,17623)
#   switch_fault(switch3,17624)
#   switch_fault(switch3,17625)
#   switch_fault(switch3,17626)
#   switch_fault(switch3,17627)
#   switch_fault(switch3,17628)
#   switch_fault(switch3,17629)
#   switch_fault(switch3,17630)
#   switch_fault(switch3,17631)
#   switch_fault(switch3,17632)
#   switch_fault(switch3,17633)
#   switch_fault(switch3,17634)
#   switch_fault(switch3,17635)
#   switch_fault(switch3,17636)
#   switch_fault(switch3,17637)
#   switch_fault(switch3,17638)
#   switch_fault(switch3,17639)
#   switch_fault(switch3,17640)
#   switch_fault(switch3,17641)
#   switch_fault(switch3,17642)
#   switch_fault(switch3,17643)
#   switch_fault(switch3,17644)
#   switch_fault(switch3,17645)
#   switch_fault(switch3,17646)
#   switch_fault(switch3,17647)
#   switch_fault(switch3,17648)
#   switch_fault(switch3,17649)
#   switch_fault(switch3,17650)
#   switch_fault(switch3,17651)
#   switch_fault(switch3,17652)
#   switch_fault(switch3,17653)
#   switch_fault(switch3,17654)
#   switch_fault(switch3,17655)
#   switch_fault(switch3,17656)
#   switch_fault(switch3,17657)
#   switch_fault(switch3,17658)
#   switch_fault(switch3,17659)
#   switch_fault(switch3,17660)
#   switch_fault(switch3,17661)
#   switch_fault(switch3,17662)
#   switch_fault(switch3,17663)
#   switch_fault(switch3,17664)
#   switch_fault(switch3,17665)
#   switch_fault(switch3,17666)
#   switch_fault(switch3,17667)
#   switch_fault(switch3,17668)
#   switch_fault(switch3,17669)
#   switch_fault(switch3,17670)
#   switch_fault(switch3,17671)
#   switch_fault(switch3,17672)
#   switch_fault(switch3,17673)
#   switch_fault(switch3,17674)
#   switch_fault(switch3,17675)
#   switch_fault(switch3,17676)
#   switch_fault(switch3,17677)
#   switch_fault(switch3,17678)
#   switch_fault(switch3,17679)
#   switch_fault(switch3,17680)
#   switch_fault(switch3,17681)
#   switch_fault(switch3,17682)
#   switch_fault(switch3,17683)
#   switch_fault(switch3,17684)
#   switch_fault(switch3,17685)
#   switch_fault(switch3,17686)
#   switch_fault(switch3,17687)
#   switch_fault(switch3,17688)
#   switch_fault(switch3,17689)
#   switch_fault(switch3,17690)
#   switch_fault(switch3,17691)
#   switch_fault(switch3,17692)
#   switch_fault(switch3,17693)
#   switch_fault(switch3,17694)
#   switch_fault(switch3,17695)
#   switch_fault(switch3,17696)
#   switch_fault(switch3,17697)
#   switch_fault(switch3,17698)
#   switch_fault(switch3,17699)
#   switch_fault(switch3,17700)
#   switch_fault(switch3,17701)
#   switch_fault(switch3,17702)
#   switch_fault(switch3,17703)
#   switch_fault(switch3,17704)
#   switch_fault(switch3,17705)
#   switch_fault(switch3,17706)
#   switch_fault(switch3,17707)
#   switch_fault(switch3,17708)
#   switch_fault(switch3,17709)
#   switch_fault(switch3,17710)
#   switch_fault(switch3,17711)
#   switch_fault(switch3,17712)
#   switch_fault(switch3,17713)
#   switch_fault(switch3,17714)
#   switch_fault(switch3,17715)
#   switch_fault(switch3,17716)
#   switch_fault(switch3,17717)
#   switch_fault(switch3,17718)
#   switch_fault(switch3,17719)
#   switch_fault(switch3,17720)
#   switch_fault(switch3,17721)
#   switch_fault(switch3,17722)
#   switch_fault(switch3,17723)
#   switch_fault(switch3,17724)
#   switch_fault(switch3,17725)
#   switch_fault(switch3,17726)
#   switch_fault(switch3,17727)
#   switch_fault(switch3,17728)
#   switch_fault(switch3,17729)
#   switch_fault(switch3,17730)
#   switch_fault(switch3,17731)
#   switch_fault(switch3,17732)
#   switch_fault(switch3,17733)
#   switch_fault(switch3,17734)
#   switch_fault(switch3,17735)
#   switch_fault(switch3,17736)
#   switch_fault(switch3,17737)
#   switch_fault(switch3,17738)
#   switch_fault(switch3,17739)
#   switch_fault(switch3,17740)
#   switch_fault(switch3,17741)
#   switch_fault(switch3,17742)
#   switch_fault(switch3,17743)
#   switch_fault(switch3,17744)
#   switch_fault(switch3,17745)
#   switch_fault(switch3,17746)
#   switch_fault(switch3,17747)
#   switch_fault(switch3,17748)
#   switch_fault(switch3,17749)
#   switch_fault(switch3,17750)
#   switch_fault(switch3,17751)
#   switch_fault(switch3,17752)
#   switch_fault(switch3,17753)
#   switch_fault(switch3,17754)
#   switch_fault(switch3,17755)
#   switch_fault(switch3,17756)
#   switch_fault(switch3,17757)
#   switch_fault(switch3,17758)
#   switch_fault(switch3,17759)
#   switch_fault(switch3,17760)
#   switch_fault(switch3,17761)
#   switch_fault(switch3,17762)
#   switch_fault(switch3,17763)
#   switch_fault(switch3,17764)
#   switch_fault(switch3,17765)
#   switch_fault(switch3,17766)
#   switch_fault(switch3,17767)
#   switch_fault(switch3,17768)
#   switch_fault(switch3,17769)
#   switch_fault(switch3,17770)
#   switch_fault(switch3,17771)
#   switch_fault(switch3,17772)
#   switch_fault(switch3,17773)
#   switch_fault(switch3,17774)
#   switch_fault(switch3,17775)
#   switch_fault(switch3,17776)
#   switch_fault(switch3,17777)
#   switch_fault(switch3,17778)
#   switch_fault(switch3,17779)
#   switch_fault(switch3,17780)
#   switch_fault(switch3,17781)
#   switch_fault(switch3,17782)
#   switch_fault(switch3,17783)
#   switch_fault(switch3,17784)
#   switch_fault(switch3,17785)
#   switch_fault(switch3,17786)
#   switch_fault(switch3,17787)
#   switch_fault(switch3,17788)
#   switch_fault(switch3,17789)
#   switch_fault(switch3,17790)
#   switch_fault(switch3,17791)
#   switch_fault(switch3,17792)
#   switch_fault(switch3,17793)
#   switch_fault(switch3,17794)
#   switch_fault(switch3,17795)
#   switch_fault(switch3,17796)
#   switch_fault(switch3,17797)
#   switch_fault(switch3,17798)
#   switch_fault(switch3,17799)
#   switch_fault(switch3,17800)
#   switch_fault(switch3,17801)
#   switch_fault(switch3,17802)
#   switch_fault(switch3,17803)
#   switch_fault(switch3,17804)
#   switch_fault(switch3,17805)
#   switch_fault(switch3,17806)
#   switch_fault(switch3,17807)
#   switch_fault(switch3,17808)
#   switch_fault(switch3,17809)
#   switch_fault(switch3,17810)
#   switch_fault(switch3,17811)
#   switch_fault(switch3,17812)
#   switch_fault(switch3,17813)
#   switch_fault(switch3,17814)
#   switch_fault(switch3,17815)
#   switch_fault(switch3,17816)
#   switch_fault(switch3,17817)
#   switch_fault(switch3,17818)
#   switch_fault(switch3,17819)
#   switch_fault(switch3,17820)
#   switch_fault(switch3,17821)
#   switch_fault(switch3,17822)
#   switch_fault(switch3,17823)
#   switch_fault(switch3,17824)
#   switch_fault(switch3,17825)
#   switch_fault(switch3,17826)
#   switch_fault(switch3,17827)
#   switch_fault(switch3,17828)
#   switch_fault(switch3,17829)
#   switch_fault(switch3,17830)
#   switch_fault(switch3,17831)
#   switch_fault(switch3,17832)
#   switch_fault(switch3,17833)
#   switch_fault(switch3,17834)
#   switch_fault(switch3,17835)
#   switch_fault(switch3,17836)
#   switch_fault(switch3,17837)
#   switch_fault(switch3,17838)
#   switch_fault(switch3,17839)
#   switch_fault(switch3,17840)
#   switch_fault(switch3,17841)
#   switch_fault(switch3,17842)
#   switch_fault(switch3,17843)
#   switch_fault(switch3,17844)
#   switch_fault(switch3,17845)
#   switch_fault(switch3,17846)
#   switch_fault(switch3,17847)
#   switch_fault(switch3,17848)
#   switch_fault(switch3,17849)
#   switch_fault(switch3,17850)
#   switch_fault(switch3,17851)
#   switch_fault(switch3,17852)
#   switch_fault(switch3,17853)
#   switch_fault(switch3,17854)
#   switch_fault(switch3,17855)
#   switch_fault(switch3,17856)
#   switch_fault(switch3,17857)
#   switch_fault(switch3,17858)
#   switch_fault(switch3,17859)
#   switch_fault(switch3,17860)
#   switch_fault(switch3,17861)
#   switch_fault(switch3,17862)
#   switch_fault(switch3,17863)
#   switch_fault(switch3,17864)
#   switch_fault(switch3,17865)
#   switch_fault(switch3,17866)
#   switch_fault(switch3,17867)
#   switch_fault(switch3,17868)
#   switch_fault(switch3,17869)
#   switch_fault(switch3,17870)
#   switch_fault(switch3,17871)
#   switch_fault(switch3,17872)
#   switch_fault(switch3,17873)
#   switch_fault(switch3,17874)
#   switch_fault(switch3,17875)
#   switch_fault(switch3,17876)
#   switch_fault(switch3,17877)
#   switch_fault(switch3,17878)
#   switch_fault(switch3,17879)
#   switch_fault(switch3,17880)
#   switch_fault(switch3,17881)
#   switch_fault(switch3,17882)
#   switch_fault(switch3,17883)
#   switch_fault(switch3,17884)
#   switch_fault(switch3,17885)
#   switch_fault(switch3,17886)
#   switch_fault(switch3,17887)
#   switch_fault(switch3,17888)
#   switch_fault(switch3,17889)
#   switch_fault(switch3,17890)
#   switch_fault(switch3,17891)
#   switch_fault(switch3,17892)
#   switch_fault(switch3,17893)
#   switch_fault(switch3,17894)
#   switch_fault(switch3,17895)
#   switch_fault(switch3,17896)
#   switch_fault(switch3,17897)
#   switch_fault(switch3,17898)
#   switch_fault(switch3,17899)
#   switch_fault(switch3,17900)
#   switch_fault(switch3,17901)
#   switch_fault(switch3,17902)
#   switch_fault(switch3,17903)
#   switch_fault(switch3,17904)
#   switch_fault(switch3,17905)
#   switch_fault(switch3,17906)
#   switch_fault(switch3,17907)
#   switch_fault(switch3,17908)
#   switch_fault(switch3,17909)
#   switch_fault(switch3,17910)
#   switch_fault(switch3,17911)
#   switch_fault(switch3,17912)
#   switch_fault(switch3,17913)
#   switch_fault(switch3,17914)
#   switch_fault(switch3,17915)
#   switch_fault(switch3,17916)
#   switch_fault(switch3,17917)
#   switch_fault(switch3,17918)
#   switch_fault(switch3,17919)
#   switch_fault(switch3,17920)
#   switch_fault(switch3,17921)
#   switch_fault(switch3,17922)
#   switch_fault(switch3,17923)
#   switch_fault(switch3,17924)
#   switch_fault(switch3,17925)
#   switch_fault(switch3,17926)
#   switch_fault(switch3,17927)
#   switch_fault(switch3,17928)
#   switch_fault(switch3,17929)
#   switch_fault(switch3,17930)
#   switch_fault(switch3,17931)
#   switch_fault(switch3,17932)
#   switch_fault(switch3,17933)
#   switch_fault(switch3,17934)
#   switch_fault(switch3,17935)
#   switch_fault(switch3,17936)
#   switch_fault(switch3,17937)
#   switch_fault(switch3,17938)
#   switch_fault(switch3,17939)
#   switch_fault(switch3,17940)
#   switch_fault(switch3,17941)
#   switch_fault(switch3,17942)
#   switch_fault(switch3,17943)
#   switch_fault(switch3,17944)
#   switch_fault(switch3,17945)
#   switch_fault(switch3,17946)
#   switch_fault(switch3,17947)
#   switch_fault(switch3,17948)
#   switch_fault(switch3,17949)
#   switch_fault(switch3,17950)
#   switch_fault(switch3,17951)
#   switch_fault(switch3,17952)
#   switch_fault(switch3,17953)
#   switch_fault(switch3,17954)
#   switch_fault(switch3,17955)
#   switch_fault(switch3,17956)
#   switch_fault(switch3,17957)
#   switch_fault(switch3,17958)
#   switch_fault(switch3,17959)
#   switch_fault(switch3,17960)
#   switch_fault(switch3,17961)
#   switch_fault(switch3,17962)
#   switch_fault(switch3,17963)
#   switch_fault(switch3,17964)
#   switch_fault(switch3,17965)
#   switch_fault(switch3,17966)
#   switch_fault(switch3,17967)
#   switch_fault(switch3,17968)
#   switch_fault(switch3,17969)
#   switch_fault(switch3,17970)
#   switch_fault(switch3,17971)
#   switch_fault(switch3,17972)
#   switch_fault(switch3,17973)
#   switch_fault(switch3,17974)
#   switch_fault(switch3,17975)
#   switch_fault(switch3,17976)
#   switch_fault(switch3,17977)
#   switch_fault(switch3,17978)
#   switch_fault(switch3,17979)
#   switch_fault(switch3,17980)
#   switch_fault(switch3,17981)
#   switch_fault(switch3,17982)
#   switch_fault(switch3,17983)
#   switch_fault(switch3,17984)
#   switch_fault(switch3,17985)
#   switch_fault(switch3,17986)
#   switch_fault(switch3,17987)
#   switch_fault(switch3,17988)
#   switch_fault(switch3,17989)
#   switch_fault(switch3,17990)
#   switch_fault(switch3,17991)
#   switch_fault(switch3,17992)
#   switch_fault(switch3,17993)
#   switch_fault(switch3,17994)
#   switch_fault(switch3,17995)
#   switch_fault(switch3,17996)
#   switch_fault(switch3,17997)
#   switch_fault(switch3,17998)
#   switch_fault(switch3,17999)
#   switch_fault(switch3,18000)
#   switch_fault(switch3,18001)
#   switch_fault(switch3,18002)
#   switch_fault(switch3,18003)
#   switch_fault(switch3,18004)
#   switch_fault(switch3,18005)
#   switch_fault(switch3,18006)
#   switch_fault(switch3,18007)
